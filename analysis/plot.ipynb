# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
matplotlib inline

# %%
data = pd.read_csv('../output/combined.csv')

# %%
pp.plot(data["1:Person"])

# %%
pp.plot(data["3:Person"])

# %%
pp.plot(data["4:Person"])
